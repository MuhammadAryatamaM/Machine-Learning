# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadAryatamaM/Machine-Learning/blob/main/Praktikum1/T1_244107020028_Muhammad_Aryatama_M.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scipy wandb pyprep wfdb ishneholterlib pycrc scikit-learn
# !pip install pyecg --no-deps

# %%
import wandb
import scipy
import pyprep
import pyecg
